# %%
import pandas as pd
import sqlalchemy as db
import numpy as np
import matplotlib.pyplot as plt
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy import Column, Integer, Float,String,DateTime,MetaData,Table
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session, mapper, sessionmaker
import seaborn as sns

# %matplotlib inline

# %%
# !ssh -i ../Jocelyn-IAM-keypair.pem -t -fN -L 3307:localhost:3306 ec2-user@18.209.226.55

# %%
sns.set_style('ticks')

# %%
for i in range(1,2000):
    conn = engine.connect()
    #some simple data operations
    conn.close()
engine.dispose()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-3d01c274c50b> in <module>
#       1 for i in range(1,2000):
# ----> 2     conn = engine.connect()
#       3     #some simple data operations
#       4     conn.close()
#       5 engine.dispose()
#
# NameError: name 'engine' is not defined

# %%
ttype = dbconnect.execute("select tindex, term from tindex;")
i = 0
ttype_lookup = {}
for result in ttype:
    i+=1
    ttype_lookup[result[0]] = result[1]
    if i ==10:
        break

# %%
ttype_lookup
# Out:
# {1: 'Uncategorized',
#  2: 'The Menu',
#  3: 'Footer Left',
#  4: 'Wine, Beer And Spirits Articles',
#  6: 'Facts',
#  7: 'Rosé',
#  8: 'quote',
#  9: 'Wine 101 - Taste',
#  10: 'Wine 101 Sub-Nav',
#  11: 'Social Footer'}

# %%
# mysql_login = "vinepair"
# mysql_pass = "zinfind#l"
# mysql_host = "127.0.0.1"
# mysql_port = 3306
# database = "vinepair1"

sql_connect  =  'mysql+pymysql://root:harvey@127.0.0.1:3306/vinepair1'

engine = db.create_engine(sql_connect)#, echo = True)

# %%
dbconnect = engine.connect()

# %%
print(pd.read_sql('Show tables', dbconnect));
print('---------------------------------------')
print(pd.read_sql("select * from pagedata limit 10", dbconnect));
print('---------------------------------------')
print(pd.read_sql("select * from pindex limit 10", dbconnect));
print('---------------------------------------')

print(pd.read_sql("select * from pterms limit 10", dbconnect));
print('---------------------------------------')

print(pd.read_sql("select * from searchdata limit 10", dbconnect));
print('---------------------------------------')

print(pd.read_sql("select * from tindex limit 10", dbconnect));
print('---------------------------------------')

print(pd.read_sql("select * from ttype limit 10", dbconnect));
# Out:
#   Tables_in_vinepair1
# 0            pagedata
# 1              pindex
# 2              pterms
# 3          searchdata
# 4              tindex
# 5               ttype
# ---------------------------------------
#    id  pindex       date       key  count
# 0   1   12839 2018-01-01  sessions   38.0
# 1   2   31480 2018-01-01  sessions    5.0
# 2   3    3578 2018-01-01  sessions    1.0
# 3   4   29730 2018-01-01  sessions    7.0
# 4   5   32698 2018-01-01  sessions   20.0
# 5   6   30018 2018-01-01  sessions    2.0
# 6   7   35747 2018-01-01  sessions    6.0
# 7   8   27577 2018-01-01  sessions   20.0
# 8   9   36511 2018-01-01  sessions   47.0
# 9  10   23211 2018-01-01  sessions    0.0
# ---------------------------------------
#    id                                               slug  pindex
# 0   1                                               null       0
# 1   2                                               null       0
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-4868d0cc2e4a> in <module>
# ----> 1 make_query("select * from pagedata where date = 2018-01-01;")
#
# NameError: name 'make_query' is not defined

# %%
pterms = pd.read_sql("select * from pterms;", dbconnect)
pterms['term_int'] = pterms['termstr'].str.split(',')

pterms_long = pterms['term_int'].apply(lambda x: pd.Series(x)).stack().reset_index(level=1, drop=True)\
.to_frame('term_int').join(pterms[['pindex']], how='left').apply(pd.to_numeric)
pterms.shape
# Out:
# (11258, 4)

# %%
pterms_long[pterms_long['term_int']==1882]
# Out:
# Empty DataFrame
# Columns: [term_int, pindex]
# Index: []

# %%
pd.read_sql('select * from pterms where pindex = 46656;', dbconnect)
# Out:
#      id                                        termstr  pindex
# 0  5665  4,74,279,474,881,894,1100,1127,1129,1582,2512   46656

# %%
pd.read_sql('select * from pindex where pindex = 46656;', dbconnect)
# Out:
#      id                                   slug  pindex
# 0  4852  best-chilean-cabernet-sauvignon-panel   46656

# %%
pd.read_sql('select * from tindex where tindex = 2512;', dbconnect)
# Out:
#      id           term  tindex
# 0  2395  blind tasting    2512

# %%
pind1 = find_pindexes(pd.Series([1127]))
pind2 = find_pindexes(pd.Series([578,1880]))
pind1
# Out:
# array([75382, 46656, 46733, 57945, 74770, 55720, 56040, 59951, 28575,
#        75221])

# %%
'select tindex from tindex where lower(term) '+country_term_query['england']
# Out:
# "select tindex from tindex where lower(term) = 'england' or where lower(term) = 'great britain';"

# %%
## Countries
country_term_query = {
    'italy': "= 'italy';",
    'france':"like '%%france';",
    'spain':"= 'spain';" ,
    'argentina': " = 'argentina';",
    'chile':"like '%%chile%%';" ,
    'nz':"= 'new zealand';",
    'sa':"= 'south africa';",
    'greece':"= 'greece';",
    'portugal':"= 'portugal';",
    'australia':"like '%%australia';",
    'austria':"= 'austria';",
    'germany':"= 'germany';",
    'england':"= 'england' or lower(term) = 'great britain';",
    'mexico':"= 'mexico';",
    'israel':"like 'israel%%'", 
    'lebanon':"= 'lebanon';",
    'us':"= 'usa' or lower(term) = 'american wine' or lower(term) = 'america';"
}

wine_term_query = {
    'rose' :"like 'ros_';",
    'malbec':"= 'malbec';",
    'moscato':"= 'moscato';",
    'cab_sav':"= 'cabernet sauvignon';",
    'pin_noir':"= 'pinot noir';",
    'merlot':"= 'merlot';",
    'riesling':"= 'riesling';",
    'sav_blanc':"= 'sauvignon blanc';",
    'red_blend':"= 'red blend';",
    'chard':"= 'chardonnay';",
    'syrah_shiraz':"like '%%syrah%%' or lower(term) like '%%shiraz%%';",
    'pin_gri':"like '%%pinot grigio%%' or lower(term) = '%%pinot gris%%';"
 }
    
 #'vin de france', 'southwest france'
 #'wines of chile'
 # 'south australia', 'wine australia', 'western australia'
 #'israeli wine'

# %%
def get_tindexes(sql_query_end):
    tindexes = pd.read_sql('select tindex from tindex where lower(term) '+sql_query_end, dbconnect)['tindex']
    return tindexes

def find_pindexes(tindexes, print_counts = False):
    pinds = pterms_long[pterms_long['term_int'].isin(tindexes.values)]
    pinds = pinds['pindex'].unique()
    if print_counts == True:
        print(len(pinds))
    return pinds

def page_overlap(pinds1, pinds2, print_counts = False):
    p_overlap = np.intersect1d(pinds1, pinds2)
    if print_counts == True:
        print('Pind1: ', len(pinds1), 'Pind2: ', len(pinds2), 'Overlap: ', len(p_overlap))
    return p_overlap

def wine_page_counts_indexes(tindexes):
    pind = find_pindexes(tindexes)
    query = "select * from pagedata where `key`='pageviews' and pindex in "+str(tuple(pind.tolist()), )
    wine_page = pd.read_sql(query, dbconnect)
    return wine_page

def wine_page_counts_indexes(tindexes):
    pind = find_pindexes(tindexes)
    query = "select * from pagedata where `key`='pageviews' and pindex in "+str(tuple(pind.tolist()), )
    wine_page = pd.read_sql(query, dbconnect)
    return wine_page

# %%
for key in country_term_query.keys():

sql_query = "like '%%wine%%' and lower(term) not like 'wine, beer%%';"
page_overlap(chile_pinds, find_pindexes(get_tindexes(sql_query)), True)

# %%
sql_query = "like '%%wine%%' and lower(term) not like 'wine, beer%%';"
page_overlap(chile_pinds, find_pindexes(get_tindexes(sql_query)), True)
# Out:
# Pind1:  41 Pind2:  5605 Overlap:  23
# array([28575, 39158, 46656, 46733, 50024, 50098, 55720, 56040, 57945,
#        59951, 63801, 63961, 64011, 64032, 64040, 64043, 74770, 75221,
#        75382, 75727, 76044, 76295, 76877])

# %%
num_pages_country = {}
for key in country_term_query.keys():
    count = len(find_pindexes(get_tindexes(country_term_query[key])))
    num_pages_country[key]=count
    
num_pages_wine = {}
for key in wine_term_query.keys():
    count = len(find_pindexes(get_tindexes(wine_term_query[key])))
    num_pages_wine[key] = count

chile_pinds = find_pindexes(get_tindexes(country_term_query['chile']))
for key in wine_term_query.keys():
    print(key)
    pinds2 = find_pindexes(get_tindexes(wine_term_query[key]))
    print(page_overlap(chile_pinds, pinds2, True))
# pinds1 = find_pindexes(get_tindexes(country_term_query['chile']))
# pinds2 = find_pindexes(get_tindexes(wine_term_query['cab_sav']))
# page_overlap(pinds1, pinds2, True)
# Out:
# rose
# Pind1:  41 Pind2:  408 Overlap:  1
# [39158]
# malbec
# Pind1:  41 Pind2:  115 Overlap:  0
# []
# moscato
# Pind1:  41 Pind2:  23 Overlap:  0
# []
# cab_sav
# Pind1:  41 Pind2:  413 Overlap:  11
# [28575 46656 46733 55720 56040 57945 59951 74770 75221 75382 75727]
# pin_noir
# Pind1:  41 Pind2:  444 Overlap:  4
# [55720 56040 57945 76877]
# merlot
# Pind1:  41 Pind2:  162 Overlap:  0
# []
# riesling
# Pind1:  41 Pind2:  162 Overlap:  0
# []
# sav_blanc
# Pind1:  41 Pind2:  250 Overlap:  5
# [46733 55720 56040 57945 59951]
# red_blend
# Pind1:  41 Pind2:  281 Overlap:  0
# []
# chard
# Pind1:  41 Pind2:  448 Overlap:  11
# [46733 55720 56040 57945 59951 64011 64032 64040 64043 76044 76295]
# syrah_shiraz
# Pind1:  41 Pind2:  129 Overlap:  1
# [56040]
# pin_gri
# Pind1:  41 Pind2:  78 Overlap:  0
# []

# %%
plt.bar(*zip(*num_pages_wine.items()))
plt.xticks(rotation = 'vertical')
plt.show()

plt.bar(*zip(*num_pages_country.items()))
plt.xticks(rotation = 'vertical')
plt.show()

# %%
chile_pinds = find_pindexes(get_tindexes(country_term_query['chile']))
chil_type = {}
for key in wine_term_query.keys():
    print(key)
    pinds2 = find_pindexes(get_tindexes(wine_term_query[key]))
    pages = page_overlap(chile_pinds, pinds2)
    chil_type[key]=len(pages)
    if len(pages) == 1:
        slugs = pd.read_sql("select * from pindex where pindex = "+str(pages[0])+';', dbconnect)  
        print(slugs)
    elif len(pages) == 0:
        print('NONE')
    else:
        slugs = pd.read_sql("select * from pindex where pindex in "+str(tuple(pages.tolist()))+';', dbconnect)
        print(slugs)
        
plt.bar(*zip(*chil_type.items()))
plt.xticks(rotation = 'vertical')
plt.show()
# Out:
# rose
#      id                     slug  pindex
# 0  2680  lapostolle-le-rose-2016   39158
# malbec
# NONE
# moscato
# NONE
# cab_sav
#       id                                               slug  pindex
# 0   4056  heres-your-visual-guide-to-chilean-wine-infogr...   59951
# 1   4181                  chile-wine-barbecue-pairing-guide   57945
# 2   4305                                   chile-wine-guide   56040
# 3   4330                              chile-infographic-map   55720
# 4   4767                                take-3-chilean-wine   46733
# 5   4852              best-chilean-cabernet-sauvignon-panel   46656
# 6   6037  flank-steak-with-pebre-sauce-and-chilean-caber...   28575
# 7   9238            behind-rise-cabernet-sauvignon-in-chile   74770
# 8   9302            steak-and-chilean-cab-a-perfect-pairing   75221
# 9   9322   understanding-cabernet-sauvignon-aging-potential   75382
# 10  9392                                               null   75727
# pin_noir
# ...

# %%
str(tuple(find_pindexes(get_tindexes(country_term_query['chile'])).tolist()))
# Out:
# '(67305, 6038, 71769, 39158, 40978, 75382, 75727, 76044, 76877, 46656, 46733, 15633, 50024, 50098, 17421, 17428, 17451, 17474, 17478, 19834, 57945, 20744, 74770, 55720, 56040, 64011, 64040, 56795, 59951, 48305, 28575, 75221, 63801, 63951, 63961, 63975, 64032, 64043, 76295, 32203, 32383)'

# %%
chile_pinds = str(tuple(find_pindexes(get_tindexes(country_term_query['chile'])).tolist()))
print(pd.read_sql("select slug from pindex where pindex in "+ chile_pinds+";", dbconnect))
# Out:
#                                                  slug
# 0                                 dead-rabbit-whiskey
# 1                            irish-pub-rent-on-airbnb
# 2                        notorious-mma-debuts-whiskey
# 3                        guinness-will-give-you-a-pub
# 4                   marques-de-casa-concha-chardonnay
# 5                               los-vascos-chardonnay
# 6                          emiliana-natura-chardonnay
# 7                             walnut-crest-chardonnay
# 8                             lapostolle-le-rose-2016
# 9                   irish-laborers-drank-14-beers-day
# 10                     best-irish-cream-whiskey-craft
# 11                                     fake-irish-pub
# 12                       poitin-irish-moonshine-guide
# 13  heres-your-visual-guide-to-chilean-wine-infogr...
# 14                  chile-wine-barbecue-pairing-guide
# 15                                   chile-wine-guide
# ...

# %%
info_map = 55720
bbq = 57945
infograph = 59951
wine_guide = 56040
rose = 39158
pinot = 76877
chard =  64040

cab1 =74770
cab2 =75221
cab3 =46656

chile_test = [info_map, bbq, infograph, wine_guide]
for i in range(len(chile_test)):
    print('page index:', chile_test[i])
    print(pd.read_sql("select slug from pindex where pindex = "+ str(int(chile_test[i]))+";", dbconnect).iloc[0])
    tinds = tuple(pterms_long[pterms_long['pindex']==chile_test[i]]['term_int'].tolist())
    print(tinds)
    print(sorted(pd.read_sql("select term from tindex where tindex in " + str(tinds), dbconnect)['term'].tolist()))
    print('-------------------------------------------------------------------------')
    query = "select * from pagedata where `key`='pageviews' and pindex = "+str(chile_test[i])
    pageviews = pd.read_sql(query, dbconnect)
    pageviews.groupby(['date'])['count'].agg('sum').plot()
    
plt.legend(['InfoMap', 'BBQ', 'InfoGraph', 'Wine Guide'])
plt.yscale('log')
plt.show()



chile_test = [rose, pinot, chard]
for i in range(len(chile_test)):
    print('page index:', chile_test[i])
    print(pd.read_sql("select slug from pindex where pindex = "+ str(int(chile_test[i]))+";", dbconnect).iloc[0])
    tinds = tuple(pterms_long[pterms_long['pindex']==chile_test[i]]['term_int'].tolist())
    print(tinds)
    print(sorted(pd.read_sql("select term from tindex where tindex in " + str(tinds), dbconnect)['term'].tolist()))
    print('-------------------------------------------------------------------------')
    query = "select * from pagedata where `key`='pageviews' and pindex = "+str(chile_test[i])
    pageviews = pd.read_sql(query, dbconnect)
    pageviews.groupby(['date'])['count'].agg('sum').plot()
    
plt.legend(['Rose', 'PinNoir', 'chard'])
plt.yscale('log')
plt.show()

chile_test = [cab1, cab2, cab3]
for i in range(len(chile_test)):
    print('page index:', chile_test[i])
    print(pd.read_sql("select slug from pindex where pindex = "+ str(int(chile_test[i]))+";", dbconnect).iloc[0])
    tinds = tuple(pterms_long[pterms_long['pindex']==chile_test[i]]['term_int'].tolist())
    print(tinds)
    print(sorted(pd.read_sql("select term from tindex where tindex in " + str(tinds), dbconnect)['term'].tolist()))
    print('-------------------------------------------------------------------------')
    query = "select * from pagedata where `key`='pageviews' and pindex = "+str(chile_test[i])
    pageviews = pd.read_sql(query, dbconnect)
    pageviews.groupby(['date'])['count'].agg('sum').plot()
    
plt.legend(['cab1', 'cab2', 'cab3'])
plt.yscale('log')
plt.show()
# Out:
# page index: 55720
# slug    chile-infographic-map
# Name: 0, dtype: object
# (4, 44, 74, 150, 279, 317, 579, 881, 894, 1017, 1073, 1100, 1127, 1129, 1138, 1152, 1207, 1241)
# ['Cabernet Sauvignon', 'Carménère', 'Chardonnay', 'Infographics', 'Pinot Noir', 'Reading About Drinking', 'Sauvignon Blanc', 'VinePair Staff', 'Wine', 'Wine', 'Wine, Beer And Spirits Articles', 'cabernet sauvignon', 'carmenere', 'cure', 'map', 'sauvignon blanc', 'wine regions', 'wines of chile']
# -------------------------------------------------------------------------
# page index: 57945
# slug    chile-wine-barbecue-pairing-guide
# Name: 0, dtype: object
# (4, 32, 74, 508, 579, 881, 1100, 1127, 1129, 1138, 1152, 1207, 1241, 1963, 3319)
# ['Cabernet Sauvignon', 'Carménère', 'Chardonnay', 'Pinot Noir', 'Reading About Drinking', 'Sauvignon Blanc', 'Wine', 'Wine', 'Wine, Beer And Spirits Articles', 'alexm', 'barbecue', 'cure', 'food', 'porter', 'wines of chile']
# ...

# %%
rose_ind = pd.read_sql("select tindex from tindex where lower(term) like 'ros_';", dbconnect)['tindex']
mal_ind = pd.read_sql("select tindex from tindex where lower(term) = 'malbec';", dbconnect)['tindex']
mosc_ind = pd.read_sql("select tindex from tindex where lower(term) = 'moscato';", dbconnect)['tindex']
rose_page = wine_page(rose_ind)
mal_page = wine_page(mal_ind)
mosc_page = wine_page(mosc_ind)
plt.figure(figsize = (10,4))
rose_page.groupby(['date'])['count'].agg('sum').plot()
mal_page.groupby(['date'])['count'].agg('sum').plot()
mosc_page.groupby(['date'])['count'].agg('sum').plot()
plt.legend(['rose', 'malbec', 'moscato'])
plt.yscale('log')
plt.show()

# %%
pind = pterms_long[pterms_long['term_int'].isin(tindexes.values)]
pind = pind['pindex'].unique()
# Out:
#         id  pindex       date        key  count
# 0  1564679      73 2018-03-20  pageviews    1.0
# 1  2234116      73 2018-04-19  pageviews    2.0
# 2  2913902      73 2018-05-18  pageviews    2.0
# 3  4029630      73 2018-06-21  pageviews    1.0
# 4  4591098      73 2018-07-08  pageviews    1.0

# %%
# wine_ind = pd.read_sql("select tindex from tindex where lower(term) like '%%wine%%';", dbconnect)['tindex']
# wine_pag = wine_page(wine_ind)
# wine_pag.groupby(['date'])['count'].agg('sum').plot()
# plt.show()
# Out:
# 2020-06-08 12:00:33,963 INFO sqlalchemy.engine.base.Engine DESCRIBE `select tindex from tindex where lower(term) like '%%%%wine%%%%';`
# 2020-06-08 12:00:33,965 INFO sqlalchemy.engine.base.Engine {}
# 2020-06-08 12:00:33,970 INFO sqlalchemy.engine.base.Engine ROLLBACK
# 2020-06-08 12:00:33,973 INFO sqlalchemy.engine.base.Engine select tindex from tindex where lower(term) like '%%wine%%';
# 2020-06-08 12:00:33,974 INFO sqlalchemy.engine.base.Engine {}
# ...

# %%
chil_ind = pd.read_sql("select tindex from tindex where lower(term) = 'chile';", dbconnect)['tindex']
gre_ind = pd.read_sql("select tindex from tindex where lower(term) = 'greece';", dbconnect)['tindex']
sa_ind = pd.read_sql("select tindex from tindex where lower(term) = 'south africa';", dbconnect)['tindex']

def wine_page(inds):
    pind = pterms_long[pterms_long['term_int'].isin(inds.values)]
    pind = pind['pindex'].unique()
    query = "select * from pagedata where `key`='pageviews' and pindex in "+str(tuple(pind.tolist()))
    #"select * from pagedata where `key`= 'pageviews' and in "
    wine_page = pd.read_sql(query, dbconnect)
    return wine_page

chil_page = wine_page(chil_ind)
gre_page = wine_page(gre_ind)
sa_page = wine_page(sa_ind)
chil_page['date'] = pd.to_datetime(chil_page['date'])
gre_page['date'] = pd.to_datetime(gre_page['date'])
sa_page['date'] = pd.to_datetime(sa_page['date'])

plt.figure(figsize = (10,4))
chil_page.groupby(['date'])['count'].agg('sum').plot()
gre_page.groupby(['date'])['count'].agg('sum').plot()
sa_page.groupby(['date'])['count'].agg('sum').plot()
plt.legend(['chile', 'greece', 'south africa'])
plt.yscale('log')
plt.show()

# %%
sa_page.head()
# Out:
#        id  pindex       date        key  count
# 0   62267   15586 2018-01-04  pageviews    1.0
# 1  176765   15586 2018-01-10  pageviews    1.0
# 2  408820   15586 2018-01-22  pageviews    1.0
# 3  565810   15586 2018-01-30  pageviews    1.0
# 4  721671   15586 2018-02-07  pageviews    2.0

# %%
total_pageviews = pd.read_sql("select date, sum(count) as total_views from pagedata where `key`='pageviews' group by date;", dbconnect)
total_pageviews = pd.read_sql("select date, sum(count) as total_views from pagedata where `key`='pageviews' group by date;", dbconnect)

# %%
type(total_pageviews['date'].iloc[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
chil_page[chil_page['date']>'2019-01-01'].groupby(['date'])['count'].agg('sum').plot()
gre_page[gre_page['date']>'2019-01-01'].groupby(['date'])['count'].agg('sum').plot()
sa_page[sa_page['date']>'2019-01-01'].groupby(['date'])['count'].agg('sum').plot()
plt.yscale('log')
plt.ylim([8e0, 1500])
plt.show()

total_pageviews[total_pageviews['date']>'2019-01-01'].plot(x ='date', y='total_views')
#plt.yscale('log')
plt.show()

# %%
Base_write = declarative_base()

class Slug(Base_write):
    __tablename__ = 'pindex'
    id = Column(Integer, primary_key=True)
    slug = Column(String(length=256),index=True)
    pindex = Column(Integer)
    def __repr__(self):
        return self.slug

class Term(Base_write):
    __tablename__ = 'tindex'
    id = Column(Integer, primary_key=True)
    term = Column(String(length=256))
    tindex = Column(Integer,index=True)
    def __repr__(self):
        return self.term
    
class Type(Base_write):
    __tablename__ = 'ttype'
    id = Column(Integer, primary_key=True)
    ttype = Column(String(length=256))
    tindex = Column(Integer,index=True)
    def __repr__(self):
        return self.ttype

class PageTerms(Base_write):
    __tablename__ = 'pterms'
    id = Column(Integer, primary_key=True)
    termstr = Column(String(length=4096),default="")
    pindex = Column(Integer,index=True)
    def __repr__(self):
        return self.termstr
    
class Pagedata(Base_write):
    __tablename__ = "pagedata"
    id = Column(Integer, primary_key=True)
    pindex = Column(Integer)
    key = Column(String(length=256))
    date = Column(DateTime)
    count = Column(Float)

class Stermdata(Base_write):
    __tablename__ = "searchdata"
    id = Column(Integer, primary_key=True)
    key = Column(String(length=256))
    sterm = Column(String(length=256))
    date = Column(DateTime)
    count = Column(Integer)

# %%
metadata = MetaData(engine)


Session = sessionmaker(bind=engine)
session = Session(engine)
